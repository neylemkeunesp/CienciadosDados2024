# %% [markdown]
# #  Manipulação de Arquivos e dados em Python

# %% [markdown]
# ## Pandas

# %%
import pandas as pd
import numpy as np

# %%
# Se quiserem fazer fora do Cocalc
lispoktab=pd.read_html( "https://pt.wikipedia.org/wiki/Lista_de_epis%C3%B3dios_de_Pok%C3%A9mon")

# %%
temporadas_pokemon = [
    {"Temporada": 1, "Geração": "Primeira", "Título EUA": "Indigo League", "Título Brasil": "Liga Índigo", "Episódios": 82, "Estreia": "1 de abril de 1997", "Final": "21 de janeiro de 1999"},
    {"Temporada": 2, "Geração": None, "Título EUA": "Adventures in the Orange Islands", "Título Brasil": "Aventuras nas Ilhas Laranja", "Episódios": 36, "Estreia": "28 de janeiro de 1999", "Final": "7 de outubro de 1999"},
    {"Temporada": 3, "Geração": "Segunda", "Título EUA": "The Johto Journeys", "Título Brasil": "A Jornada Johto", "Episódios": 41, "Estreia": "14 de outubro de 1999", "Final": "27 de julho de 2000"},
    {"Temporada": 4, "Geração": None, "Título EUA": "Johto League Champions", "Título Brasil": "Campeões da Liga Johto", "Episódios": 52, "Estreia": "3 de agosto de 2000", "Final": "2 de agosto de 2001"},
    {"Temporada": 5, "Geração": None, "Título EUA": "Master Quest", "Título Brasil": "Master Quest", "Episódios": 65, "Estreia": "9 de agosto de 2001", "Final": "14 de novembro de 2002"},
    {"Temporada": 6, "Geração": "Terceira", "Título EUA": "Advanced", "Título Brasil": "Avançado", "Episódios": 40, "Estreia": "21 de novembro de 2002", "Final": "28 de agosto de 2003"},
    {"Temporada": 7, "Geração": None, "Título EUA": "Advanced Challenge", "Título Brasil": "Desafio Avançado", "Episódios": 52, "Estreia": "4 de setembro de 2003", "Final": "2 de setembro de 2004"},
    {"Temporada": 8, "Geração": None, "Título EUA": "Advanced Battle", "Título Brasil": "Batalha Avançada", "Episódios": 54, "Estreia": "9 de setembro de 2004", "Final": "29 de setembro de 2005"},
    {"Temporada": 9, "Geração": None, "Título EUA": "Battle Frontier", "Título Brasil": "Batalha da Fronteira", "Episódios": 47, "Estreia": "6 de outubro de 2005", "Final": "14 de setembro de 2006"},
    {"Temporada": 10, "Geração": "Quarta", "Título EUA": "Diamond and Pearl", "Título Brasil": "Diamante e Pérola", "Episódios": 52, "Estreia": "28 de setembro de 2006", "Final": "25 de outubro de 2007"},
    {"Temporada": 11, "Geração": None, "Título EUA": "Battle Dimension", "Título Brasil": "Batalha Dimensional", "Episódios": 52, "Estreia": "8 de novembro de 2007", "Final": "4 de dezembro de 2008"},
    {"Temporada": 12, "Geração": None, "Título EUA": "Galactic Battles", "Título Brasil": "Batalhas Galácticas", "Episódios": 53, "Estreia": "4 de dezembro de 2008", "Final": "24 de dezembro de 2009"},
    {"Temporada": 13, "Geração": None, "Título EUA": "Sinnoh League Victors", "Título Brasil": "Vencedores da Liga Sinnoh", "Episódios": 34, "Estreia": "7 de janeiro de 2010", "Final": "9 de setembro de 2010"},
    {"Temporada": 14, "Geração": "Quinta", "Título EUA": "Black & White", "Título Brasil": "Preto e Branco", "Episódios": 50, "Estreia": "23 de setembro de 2010", "Final": "15 de setembro de 2011"},
    {"Temporada": 15, "Geração": None, "Título EUA": "Rival Destinies", "Título Brasil": "Destinos Rivais", "Episódios": 49, "Estreia": "22 de setembro de 2011", "Final": "4 de outubro de 2012"},
    {"Temporada": 16, "Geração": None, "Título EUA": "Adventures in Unova", "Título Brasil": "Aventuras em Unova", "Episódios": 25, "Estreia": "11 de outubro de 2012", "Final": "18 de abril de 2013"},
    {"Temporada": 16, "Geração": None, "Título EUA": "Adventures in Unova and Beyond", "Título Brasil": "Aventuras em Unova e Mais Além", "Episódios": 20, "Estreia": "25 de abril de 2013", "Final": "26 de setembro de 2013"},
    {"Temporada": 17, "Geração": "Sexta", "Título EUA": "XY", "Título Brasil": "XY", "Episódios": 49, "Estreia": "17 de outubro de 2013", "Final": "30 de outubro de 2014"},
    {"Temporada": 18, "Geração": None, "Título EUA": "Kalos Quest", "Título Brasil": "Desafio em Kalos", "Episódios": 44, "Estreia": "6 de novembro de 2014", "Final": "22 de outubro de 2015"},
    {"Temporada": 19, "Geração": None, "Título EUA": "XYZ", "Título Brasil": "XYZ", "Episódios": 47, "Estreia": "29 de outubro de 2015", "Final": "3 de novembro de 2016"},
    {"Temporada": 20, "Geração": "Sétima", "Título EUA": "Sun & Moon", "Título Brasil": "Sol e Lua", "Episódios": 43, "Estreia": "17 de novembro de 2016", "Final": "21 de setembro de 2017"},
    {"Temporada": 21, "Geração": None, "Título EUA": "Ultra Adventures", "Título Brasil": "Ultra Aventuras", "Episódios": 49, "Estreia": "5 de outubro de 2017", "Final": "14 de outubro de 2018"},
    {"Temporada": 22, "Geração": None, "Título EUA": "Ultra Legends", "Título Brasil": "Ultra Lendas", "Episódios": 54, "Estreia": "21 de outubro de 2018", "Final": "3 de novembro de 2019"},
    {"Temporada": 23, "Geração": "Oitava", "Título EUA": "Journeys", "Título Brasil": "Jornadas", "Episódios": 48, "Estreia": "17 de novembro de 2019", "Final": "4 de dezembro de 2020"},
    {"Temporada": 24, "Geração": None, "Título EUA": "Master Journeys", "Título Brasil": "Jornadas de Mestre", "Episódios": 42, "Estreia": "11 de dezembro de 2020", "Final": "10 de dezembro de 2021"},
    {"Temporada": 25, "Geração": None, "Título EUA": "Ultimate Journeys", "Título Brasil": "Jornadas Supremas", "Episódios": 46, "Estreia": "17 de dezembro de 2021", "Final": "16 de dezembro de 2022"},
    {"Temporada": "Especial", "Geração": None, "Título EUA": "To Be a Pokémon Master", "Título Brasil": "Mestre Pokémon", "Episódios": 11, "Estreia": "13 de janeiro de 2023", "Final": "24 de março de 2023"},
    {"Temporada": 26, "Geração": "Nona", "Título EUA": "Horizons", "Título Brasil": "Horizontes", "Episódios": 70, "Estreia": "14 de abril de 2023", "Final": "presente"}
]

# %%
df=pd.DataFrame(temporadas_pokemon)

# %%
df
# Out:
#    Temporada   Geração                        Título EUA  \
# 0          1  Primeira                     Indigo League
# 1          2      None  Adventures in the Orange Islands
# 2          3   Segunda                The Johto Journeys
# 3          4      None            Johto League Champions
# 4          5      None                      Master Quest
# 5          6  Terceira                          Advanced
# 6          7      None                Advanced Challenge
# 7          8      None                   Advanced Battle
# 8          9      None                   Battle Frontier
# 9         10    Quarta                 Diamond and Pearl
# 10        11      None                  Battle Dimension
# 11        12      None                  Galactic Battles
# 12        13      None             Sinnoh League Victors
# 13        14    Quinta                     Black & White
# 14        15      None                   Rival Destinies
# ...

# %%
lispoktab[1]
# Out:
# 0   NaN        01  Primeira                     Indigo League  \
# 0   NaN        01  Primeira                     Indigo League
# 1   NaN        02  Primeira  Adventures in the Orange Islands
# 2   NaN        03   Segunda                The Johto Journeys
# 3   NaN        04   Segunda            Johto League Champions
# 4   NaN        05   Segunda                      Master Quest
# 5   NaN        06  Terceira                          Advanced
# 6   NaN        07  Terceira                Advanced Challenge
# 7   NaN        08  Terceira                   Advanced Battle
# 8   NaN        09  Terceira                   Battle Frontier
# 9   NaN        10    Quarta                 Diamond and Pearl
# 10  NaN        11    Quarta                  Battle Dimension
# 11  NaN        12    Quarta                  Galactic Battles
# 12  NaN        13    Quarta             Sinnoh League Victors
# 13  NaN        14    Quinta                     Black & White
# ...

# %%
columns=[Temporada	Geração	Título nos EUA Estados Unidos	Titulo no Brasil Brasil	Episódios	Exibição original
Estreia	Final]

# %%
lispoktab[1]
# Out:
# 0   NaN        01  Primeira                     Indigo League  \
# 0   NaN        01  Primeira                     Indigo League
# 1   NaN        02  Primeira  Adventures in the Orange Islands
# 2   NaN        03   Segunda                The Johto Journeys
# 3   NaN        04   Segunda            Johto League Champions
# 4   NaN        05   Segunda                      Master Quest
# 5   NaN        06  Terceira                          Advanced
# 6   NaN        07  Terceira                Advanced Challenge
# 7   NaN        08  Terceira                   Advanced Battle
# 8   NaN        09  Terceira                   Battle Frontier
# 9   NaN        10    Quarta                 Diamond and Pearl
# 10  NaN        11    Quarta                  Battle Dimension
# 11  NaN        12    Quarta                  Galactic Battles
# 12  NaN        13    Quarta             Sinnoh League Victors
# 13  NaN        14    Quinta                     Black & White
# ...

# %%
df=lispoktab[2]

# %%
df
# Out:
#      0                       1
# 0    #      Numeração no anime
# 1   ##      Númeração na série
# 2  ###  Numeração na temporada

# %%
columns=df.iloc[0]
df.columns=columns
df2=df[1:]

# %%
df2
# Out:
# 0                   1                      ポケットモンスター Pocket Monsters[16]  \
# 1                   2                      ポケットモンスター Pocket Monsters[16]
# 2                   3  ポケットモンスター アドバンスジェネレーション Pocket Monsters Advanc...
# 3                   4  ポケットモンスターダイヤモンド＆パール Pocket Monsters Diamond & ...
# 4                   5  ポケットモンスターベストウイッシュ Pocket Monsters Best Wishes!...
# 5                   6                 ポケットモンスターＸＹ Pocket Monsters XY[20]
# 6                   7    ポケットモンスター　サン＆ムーン Pocket Monsters Sun & Moon[21]
# 7                   8                      ポケットモンスター Pocket Monsters[22]
# 8                   9  ポケットモンスター Pocket Monsters: Liko and Roy's Depa...
# 9  Total de Episódios                                 Total de Episódios
#
# 0      Pokémon, the Series: The Beginning  \
# 1    Pokémon, the Series: Gold and Silver
# 2  Pokémon, the Series: Ruby and Sapphire
# 3  Pokémon, the Series: Diamond and Pearl
# 4      Pokémon, the Series: Black & White
# ...

# %%
df2.columns
# Out:
# Index([                                 '1',
#             'ポケットモンスター Pocket Monsters[16]',
#        'Pokémon, the Series: The Beginning',
#                'Pokémon, a Série: O Início',
#                                         118,
#                                         276,
#                        '1 de abril de 1997',
#                    '14 de novembro de 2002'],
#       dtype='object', name=0)

# %% [markdown]
# ## Perguntas

# %% [markdown]
# Quantas regiões diferentes existem?

# %%
len(set(df2["Região"]))
# Out:
# 8

# %% [markdown]
# Construa uma coluna com o número de episódios.

# %%
strepisodios=df2["Episódios"][0]

lis=strepisodios.split("-")
lis2=[int(elem) for elem in lis]
lis2[1]-lis2[0]+1
# Out:
# 82

# %%
strepisodios=df2["Episódios"][0]
lis=strepisodios.split("-")
lis2=[int(elem) for elem in lis]
lis2[1]-lis2[0]+1
# Out:
# 83

# %%
def geraduracao(string):
    lis=string.split("-")
    lis2=[int(elem) for elem in lis]
    return lis2[1]-lis2[0]+1

# %%
teste=(df2["Episódios"].apply(geraduracao))
df2["Duração"]=teste
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app

# %%
df2
# Out:
#                                      Série                 Geração  \
# 0   Série Original (O Início/Ouro e Prata)     Primeira (O Início)
# 1   Série Original (O Início/Ouro e Prata)     Primeira (O Início)
# 2   Série Original (O Início/Ouro e Prata)  Segunda (Ouro e Prata)
# 3   Série Original (O Início/Ouro e Prata)  Segunda (Ouro e Prata)
# 4   Série Original (O Início/Ouro e Prata)  Segunda (Ouro e Prata)
# 5                            Rubi e Safira                Terceira
# 6                            Rubi e Safira                Terceira
# 7                            Rubi e Safira                Terceira
# 8                            Rubi e Safira                Terceira
# 9                        Diamante e Pérola                  Quarta
# 10                       Diamante e Pérola                  Quarta
# 11                       Diamante e Pérola                  Quarta
# 12                       Diamante e Pérola                  Quarta
# ...

# %%
gb=df2.groupby("Região")

# %%
gb["Geração"].count()
# Out:
# Região
# Alola            1
# Hoenn            3
# Ilhas Laranja    1
# Johto            3
# Kalos            3
# Kanto            2
# Sinnoh           4
# Unova            3
# Name: Geração, dtype: int64

# %%
gb["Duração"].mean()
# Out:
# Região
# Alola            43.000000
# Hoenn            48.666667
# Ilhas Laranja    35.000000
# Johto            52.666667
# Kalos            49.000000
# Kanto            65.000000
# Sinnoh           47.750000
# Unova            48.000000
# Name: Duração, dtype: float64

# %% [markdown]
# ## Exercícios
#
# - Calcule o número de episódios em cada geração.

# %% [markdown]
# ## Exemplo Tenis

# %% [markdown]
# ### Para baixar os programas use o comando (não será necessário no SageMathCloud)

# %%
# %%sh
#
# git clone https://github.com/ipython-books/cookbook-data.git
# cd cookbook-data
# unzip tennis.zip
# Out:
# Archive:  tennis.zip
#   inflating: data/Andy-Murray.csv
#   inflating: data/Novak-Djokovic.csv
#   inflating: data/Rafael-Nadal.csv
#   inflating: data/Roger-Federer.csv
# Cloning into 'cookbook-data'...

# %%
import numpy as np
import pandas as pd
player = 'Roger Federer'
filename = "./cookbook-data/data/{name}.csv".format(name=player.replace(' ', '-'))
df = pd.read_csv(filename)

# %%
df
# Out:
# WARNING: Some output was deleted.

# %%
df.columns
# Out:
# Index(['year', 'tournament', 'start date', 'type', 'surface', 'draw',
#        'atp points', 'atp ranking', 'tournament prize money', 'round',
#        'opponent', 'ranking', 'score', 'stats link', 'tournament.1',
#        'tournament round', 'time', 'winner', 'player1 name',
#        'player1 nationality', 'player1 aces', 'player1 double faults',
#        'player1 1st serves in', 'player1 1st serves total',
#        'player1 1st serve points won', 'player1 1st serve points total',
#        'player1 2nd serve points won', 'player1 2nd serve points total',
#        'player1 break points won', 'player1 break points total',
#        'player1 service games played', 'player1 1st serve return points won',
#        'player1 1st serve return points total',
#        'player1 2nd serve return points won',
#        'player1 2nd serve return points total',
#        'player1 break points converted won',
#        'player1 break points converted total', 'player1 return games played',
# ...

# %%
df["winner"] == player
# Out:
# 0       False
# 1        True
# 2        True
# 3       False
# 4       False
# 5       False
# 6        True
# 7        True
# 8        True
# 9        True
# 10       True
# 11       True
# 12      False
# 13       True
# 14       True
# 15       True
# 16      False
# 17       True
# 18       True
# 19      False
# 20       True
# 21      False
# 22       True
# 23      False
# 24      False
# 25       True
# 26      False
# 27      False
# 28      False
# 29      False
#         ...
# 1149     True
# 1150    False
# 1151     True
# 1152     True
# 1153     True
# 1154     True
# 1155     True
# 1156     True
# 1157     True
# 1158     True
# 1159     True
# 1160     True
# 1161     True
# 1162     True
# 1163     True
# 1164     True
# 1165     True
# 1166     True
# 1167     True
# 1168    False
# 1169     True
# 1170     True
# 1171     True
# 1172     True
# 1173     True
# 1174    False
# 1175     True
# 1176     True
# 1177     True
# 1178    False
# ...

# %%
df['win'] = df['winner'] == player
df['win'].tail()
# Out:
# 1174    False
# 1175     True
# 1176     True
# 1177     True
# 1178    False
# Name: win, dtype: bool

# %%
("{player} has won {vic:.0f}% "
               "of his ATP matches.").format(
                player=player, vic=100*df['win'].mean())
# Out:
# 'Roger Federer has won 82% of his ATP matches.'

# %%
df['dblfaults'] = (df['player1 double faults'] /
                   df['player1 total points total'])

# %%
df['dblfaults'].tail()
# Out:
# 1174    0.018116
# 1175    0.000000
# 1176    0.000000
# 1177    0.011561
# 1178         NaN
# Name: dblfaults, dtype: float64

# %%
gb = df.groupby('year')

# %%
gb['dblfaults'].mean()
# Out:
# year
# 1998    0.021580
# 1999    0.023588
# 2000    0.021473
# 2001    0.017495
# 2002    0.016521
# 2003    0.018611
# 2004    0.013195
# 2005    0.010575
# 2006    0.007639
# 2007    0.007388
# 2008    0.005887
# 2009    0.010379
# 2010    0.009185
# 2011    0.009136
# 2012    0.009365
# Name: dblfaults, dtype: float64

# %% [markdown]
# **Exercício:**
#
# 1. Construa uma tabela com o número de vitórias e derrotas de Federer para cada tipo de terreno.
