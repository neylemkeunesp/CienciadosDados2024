# %%
from notebook.services.config import ConfigManager
from IPython.paths import locate_profile
cm = ConfigManager(profile_dir=locate_profile(get_ipython().profile))
cm.update('livereveal', {
              'theme': 'beige',
              'transition': 'zoom',
              'start_slideshow_at': 'selected',
})
# Out:
# {'theme': 'beige', 'transition': 'zoom', 'start_slideshow_at': 'selected'}

# %% [markdown]
# # Ciência dos Dados I

# %% [markdown]
# # Acessando o Curso no ambiente Classroom

# %% [markdown]
# Iremos manter o material do Curso no Classroom.  O codigo da turma é:
#
# v5qae3k

# %% [markdown]
# # GitHub

# %% [markdown]
# O Material para esse curso está diponível também no GitHub.
#
#
# https://github.com/neylemkeunesp/CienciadosDados2022
#
#
# O GitHub facilita o processo de Download.
#
#
# Para baixar em um ambiente Linux ou Mac basta digitar
#
# ```git clone https://github.com/neylemkeunesp/CienciadosDados2022```

# %% [markdown]
# ## Exportando para PDF
#
# Será necessário Exportar eventalmente nossos resultados para PDF. Abra um terminal no Cocalc e digite:
#
# ```jupyter nbconvert --to pdf file.ipynb```

# %% [markdown]
# ## Google Colaboratory
#
# Para acessar o projeto da google acesse:
#
# https://colab.research.google.com/github/neylemkeunesp/CienciadosDados2022/blob/main
#
# O Google tem amplo suporte aos notebooks, você pode acessá-los de sua conta e pode criar novos.

# %% [markdown]
# ## Para acessar o terminal

# %%
#so funciona no colab
# !pip install colab-xterm
# %load_ext colabxterm
# %xterm
# Out:
# Collecting colab-xterm
#   Downloading colab_xterm-0.1.2-py3-none-any.whl (115 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 881.0 kB/s eta 0:00:000:00:01m eta 0:00:01
# Requirement already satisfied: ptyprocess~=0.7.0 in /Users/neylemke/opt/anaconda3/lib/python3.9/site-packages (from colab-xterm) (0.7.0)
# Requirement already satisfied: tornado>5.1 in /Users/neylemke/opt/anaconda3/lib/python3.9/site-packages (from colab-xterm) (6.1)
# Installing collected packages: colab-xterm
# Successfully installed colab-xterm-0.1.2
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-2b536bcd6e22> in <module>()
#       1 get_ipython().system('pip install colab-xterm')
# ----> 2 get_ipython().magic('load_ext colabxterm')
#       3 get_ipython().magic('xterm')
#
# /Users/neylemke/.pyenv/versions/3.6.1/lib/python3.6/site-packages/IPython/core/interactiveshell.py in magic(self, arg_s)
#    2158         magic_name, _, magic_arg_s = arg_s.partition(' ')
#    2159         magic_name = magic_name.lstrip(prefilter.ESC_MAGIC)
# -> 2160         return self.run_line_magic(magic_name, magic_arg_s)
#    2161
#    2162     #-------------------------------------------------------------------------
#
# /Users/neylemke/.pyenv/versions/3.6.1/lib/python3.6/site-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line)
#    2079                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2080             with self.builtin_trap:
# -> 2081                 result = fn(*args,**kwargs)
#    2082             return result
#    2083
#
# <decorator-gen-63> in load_ext(self, module_str)
#
# /Users/neylemke/.pyenv/versions/3.6.1/lib/python3.6/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     186     # but it's overkill for just that one bit of state.
#     187     def magic_deco(arg):
# --> 188         call = lambda f, *a, **k: f(*a, **k)
#     189
#     190         if callable(arg):
#
# /Users/neylemke/.pyenv/versions/3.6.1/lib/python3.6/site-packages/IPython/core/magics/extension.py in load_ext(self, module_str)
#      35         if not module_str:
#      36             raise UsageError('Missing module name.')
# ---> 37         res = self.shell.extension_manager.load_extension(module_str)
#      38
#      39         if res == 'already loaded':
#
# /Users/neylemke/.pyenv/versions/3.6.1/lib/python3.6/site-packages/IPython/core/extensions.py in load_extension(self, module_str)
#      81             if module_str not in sys.modules:
#      82                 with prepended_to_syspath(self.ipython_extension_dir):
# ---> 83                     __import__(module_str)
#      84             mod = sys.modules[module_str]
#      85             if self._call_load_ipython_extension(mod):
#
# ModuleNotFoundError: No module named 'colabxterm'

# %% [markdown]
# ## Kaggle
#
# O sistema kaggle é outra alternativa importante da Google. Pode ser acessado em
#
# http://kaggle.com
#
# Com a conta Google. Você pode acessar bases de dados ou ainda rodar notebooks.

# %% [markdown]
# ## Ambiente Cocalc
#
# O ambiente Cocalc é um dos mais completos ambientes para aprendizagem de Ciência dos Dados.
#
# http://cocalc.com

# %% [markdown]
# ## Comparação

# %% [markdown]
# | Feature | Colab | Cocalc | Kaggle |
# |---------|-------|--------|--------|
# | Ambiente de Desenvolvimento | S | S | S |
# | Terminal (Gratuito) | N | S | N|
# | Integração Google Drive | S | N | S |
# | Acesso a GPUs e TPUs | S | N | S |
# | Equivalente ao Jupyter | N | N | N |
# | Modo Apresentação | N | S | N |
# | Outras Linguagens | N | S | S |
